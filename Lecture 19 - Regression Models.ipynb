# %% [markdown]
# ## Regression Using Sklearn

# %% [markdown]
# #### Lecture 19 - Regression Models
#
#
# This notebook cover the following concepts
#
# 1. Regression Models using Scikit Learn
# 2. Model Evaluation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = [10,5]

# Ignore Warnings
import warnings

# Set the warning filter to ignore FutureWarning
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %% [markdown]
# ## TRAINING DATA PRE-PROCESSING
#
# The first step in the machine learning pipeline is to clean and transform the training data into a useable format for analysis and modeling.
#
# As such, data-preprocessing addressess.
#
# * Assumptions about data shape
# * incorrect data types
# * outliers or error
# * Missing values
# * Categorical Variables

# %%
full_data = pd.read_csv('USA_Housing.csv')

# %% [markdown]
# ## Data Shape
#
# after loading the dataset, I examine its shape to get better sense of the data and the information it contains.

# %%
# Data shape
print('train data: ',full_data.shape)
# Out:
# train data:  (5000, 7)

# %%
full_data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %% [markdown]
# ## Missing Data
#
# A heatmap will help better visualize what features as missing the most information

# %%
# Heatmap it will show the variation off missing values in data.
# if there is no any missing values then it will show blank

sns.heatmap(full_data.isnull(),yticklabels=False, cbar = False, cmap= 'tab20c_r')
plt.title('Missing Data: Training Set')
plt.show()

# %%
# Remove Address feature because this is the only object feature and also not affecting data 
full_data.drop('Address', axis=1, inplace=True)

# %%
full_data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05

# %%
# Remove rows with missing data
full_data.dropna(inplace=True)

# %%
full_data
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price
# ...

# %%
# Numeric summary
full_data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %% [markdown]
# ## GETTING MODEL READY
#
# Now that we have explored the data, it is time to get these features 'model ready'. categorical features will need to be converted into 'dummy variables', otherwise a machine learning algorithm will not be able to take in those features as inputs.

# %%
full_data.shape
# Out:
# (5000, 6)

# %% [markdown]
# Now the train data is perfect for machine learning algorithm:
#
# * All the data is numeric
# * Everything is concatenated together

# %% [markdown]
# ## OBJECTIVE 2: MACHINE LEARNING
#
# Next, I will feed these features into various Regression algorithms to determine the best performance using a simple framework. **Split, Fit, predict, Score It.**

# %% [markdown]
# ### target Variable Splitting
#
# -We will split Full Dataset into **Input** and **target** variables.
#
#
# -Input is also called **Feature Variables** Output refers to Target **Varaibles**

# %%
# Split data to be used in the models
# create matrix of features
x = full_data.drop('Price', axis=1)

# Create target variable
y = full_data['Price']

# %%
from sklearn import preprocessing
pre_process = preprocessing.StandardScaler().fit(x)
x_transform = pre_process.fit_transform(x)

# %%
# X Represents the features
x_transform.shape
x_transform
# Out:
# array([[ 1.02865969, -0.29692705,  0.02127433,  0.08806222, -1.31759867],
#        [ 1.00080775,  0.02590164, -0.25550611, -0.72230146,  0.40399945],
#        [-0.68462916, -0.11230283,  1.5162435 ,  0.93084045,  0.07240989],
#        ...,
#        [-0.48723454,  1.28447022, -2.17026949, -1.50025059, -0.29193658],
#        [-0.05459152, -0.44669439,  0.14154061,  1.18205319,  0.65111608],
#        [-0.28831272,  0.01521477, -0.19434166,  0.07185495,  1.04162464]])

# %%
# Y represents the target
y.shape
# Out:
# (5000,)

# %%
# Use x and y varaible to split the training data into train and test
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x_transform,y, test_size=.10, random_state=101)

# %% [markdown]
# # LINEAR REGRESSION
#
# #### Model Training

# %%
# Fit
# Import model
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler


# Create instance of model
lin_reg = LinearRegression()

# Pass training data into model
lin_reg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model Testing
#
# ### Class Prediction

# %%
# Predict

y_pred = lin_reg.predict(x_test)
print(y_pred.shape)
print(y_pred)
# Out:
# (500,)
# [1257098.09685349  822086.76211938 1739484.60206384  973128.9269703
#   993918.45735573  645734.60078802 1074412.81648685  856463.98369062
#  1445048.63352694 1201847.71924782 1454475.51805014 1296582.98910134
#  1736858.04511704 1336694.59015483 1386280.00636484 1223122.34992068
#   615840.7860361   964515.62334817 1222020.63802963 1197532.31828304
#   506756.96702134 1767894.37065039 1854829.42630351 1198521.37525139
#  1065384.60130188 1810199.62960618 1767830.26189968 1440162.9747667
#  1386122.51652193 1539972.94909227  729561.93190619 1754434.69364763
#  1465273.07428251 1026021.79840116 1283514.57970667  917688.32850804
#  1185681.03610736 1000137.89595728 1329344.79847155  784262.29954368
#  1392528.47637802  576569.30274928  823465.14446257 1893895.24014477
#  1671565.73974773  964720.06183539 1129280.90868273  792574.96874635
#  1159381.43948676 1473209.24685792 1459527.31772498 1164492.85979007
# ...

# %%
sns.scatterplot(x=y_test, y=y_pred, color='blue', label='Actual Data points')
plt.plot([min(y_test), max(y_test)], [min(y_test),max(y_test)], color='red', label= 'Ideal Line')
plt.legend()
plt.show()

# %%
# Combine Actual and Predicted values side by side
results = np.column_stack((y_test, y_pred))

# Printing the result
print("Actual Values  |  Predicted Values")
print("----------------------------------")
for actual, predicted in results:
    print(f"{actual:14.2f}  |  {predicted:12.2f}")
# Out:
# Actual Values  |  Predicted Values
# ----------------------------------
#     1251688.62  |    1257098.10
#      873048.32  |     822086.76
#     1696977.66  |    1739484.60
#     1063964.29  |     973128.93
#      948788.28  |     993918.46
#      730043.65  |     645734.60
#     1166925.15  |    1074412.82
#      705444.12  |     856463.98
#     1499988.88  |    1445048.63
#     1288199.15  |    1201847.72
#     1441736.76  |    1454475.52
#     1279681.15  |    1296582.99
#     1754969.16  |    1736858.05
#     1511653.45  |    1336694.59
#     1441956.20  |    1386280.01
#     1119992.62  |    1223122.35
#      727866.53  |     615840.79
#     1138885.10  |     964515.62
#     1074263.32  |    1222020.64
#     1386473.37  |    1197532.32
#      404643.60  |     506756.97
#     1449829.49  |    1767894.37
#     1775874.76  |    1854829.43
#     1202050.58  |    1198521.38
#     1105737.46  |    1065384.60
#     1835564.69  |    1810199.63
#     1795428.77  |    1767830.26
# ...

# %% [markdown]
# ## Residual Analysis
#
# Residual analysis in linear regression is a way to check how well the model fits the data.
# It involves looking at the differences (Residuals) between the actual data points and the predictions from the model.
#
# In a good model, the residuals should be randomly scattered around zero on a plot. If there are patterns or a fan-like shape, it suggests the model may not be the best fit. Outliers,points far from the others, can also affect the model.
#
# Residual analysis helps ensure the model's accuracy and whether it meets the assumptions of linear reggression. If issues are found, adjustements to the model may be needed to improve its perfromance.

# %%
residual = actual - y_pred.reshape(-1)
print(residual)
# Out:
# [-4.47976991e+05 -1.29656563e+04 -9.30363496e+05 -1.64007821e+05
#  -1.84797352e+05  1.63386505e+05 -2.65291711e+05 -4.73428778e+04
#  -6.35927528e+05 -3.92726613e+05 -6.45354412e+05 -4.87461883e+05
#  -9.27736939e+05 -5.27573484e+05 -5.77158901e+05 -4.14001244e+05
#   1.93280320e+05 -1.55394518e+05 -4.12899532e+05 -3.88411212e+05
#   3.02364139e+05 -9.58773265e+05 -1.04570832e+06 -3.89400269e+05
#  -2.56263495e+05 -1.00107852e+06 -9.58709156e+05 -6.31041869e+05
#  -5.77001411e+05 -7.30851843e+05  7.95591739e+04 -9.45313588e+05
#  -6.56151968e+05 -2.16900693e+05 -4.74393474e+05 -1.08567223e+05
#  -3.76559930e+05 -1.91016790e+05 -5.20223693e+05  2.48588063e+04
#  -5.83407371e+05  2.32551803e+05 -1.43440386e+04 -1.08477413e+06
#  -8.62444634e+05 -1.55598956e+05 -3.20159803e+05  1.65461371e+04
#  -3.50260334e+05 -6.64088141e+05 -6.50406212e+05 -3.55371754e+05
#  -2.89631885e+05 -5.51037037e+05 -3.40729888e+04 -1.76177411e+05
# ...

# %%
# Distribution plot for Residula (Difference between actual and predicted values)
sns.distplot(residual, kde=True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# It represents that our mode is not skewed as the distribution is center aligned but note the values of the X and Y axis they in power of 6. Which means the difference between actual and predicted value was high and but it is reduced to some extent. Which is Good.

# %% [markdown]
# ### Model Evaluation
#
# ## Linear Regression

# %%
# Score It
from sklearn.metrics import mean_squared_error

print('Linear Reggression Model')
# Results
print('--'*30)
# mean_squared_error (y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)

# print evaluation metric
print("Mean Squared Erro : ", mse)
print("Root Mean Squared Error : ", rmse)
# Out:
# Linear Reggression Model
# ------------------------------------------------------------
# Mean Squared Erro :  9839952411.80171
# Root Mean Squared Error :  99196.53427313734

# %%
y_train.shape
# Out:
# (4500,)

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

rf_regressor = DecisionTreeRegressor()
rf_regressor.fit(x_train,y_train)

#Predicting the SalePrices using test set
y_pred_rf = rf_regressor.predict(x_test)

DTr = mean_squared_error(y_pred_rf,y_test)
#Random Forest Regression Accuracy with test set
print('Decision Tree Regression : ',DTr)
# Out:
# Decision Tree Regression :  30923398276.73861

# %% [markdown]
# ## Random Forest

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

rf_regressor = RandomForestRegressor()
rf_regressor.fit(x_train,y_train)

#Predicting the SalePrices using test set
y_pred_rf = rf_regressor.predict(x_test)
RFr = mean_squared_error(y_pred_rf,y_test)
#Random Forest Regression Accuracy with test set
print('Random Forest Regression : ',RFr)
# Out:
# Random Forest Regression :  14244336842.787146

# %% [markdown]
# ## Gradient Boosting Regression

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor

rf_regressor = GradientBoostingRegressor()
rf_regressor.fit(x_train,y_train)

# Predicting the SalesPrices using test set
y_pred_rf = rf_regressor.predict(x_test)

#Random Forest Regression Accuracy with test set
GBr = mean_squared_error(y_pred_rf, y_test)
print('Gradient Boosting Regression :', GBr)
# Out:
# Gradient Boosting Regression : 12024214617.46607

# %%
# Sample model scores (replace these with your actual model scores)
model_scores = {
    "Linear Regression": 9839952411.80171,
    "Descison Tree": 30923398276.73861,
    "Random Forest": 14244336842.787146,
    "Gradient Boosting": 12024214617.46607
}

# Sort the model scores in ascendig order based on their values (lower values first)
sorted_scores = sorted(model_scores.items(), key=lambda x: x[1])

# Display the Ranking of the models
print("Model Rankings (Lower values are better):")
print("--"*21)
for rank, (model_name, score) in enumerate(sorted_scores, start=1):
    print(f"{rank}. {model_name}: {score}")
# Out:
# Model Rankings (Lower values are better):
# ------------------------------------------
# 1. Linear Regression: 9839952411.80171
# 2. Gradient Boosting: 12024214617.46607
# 3. Random Forest: 14244336842.787146
# 4. Descison Tree: 30923398276.73861
